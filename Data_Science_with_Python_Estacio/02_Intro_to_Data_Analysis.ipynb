# %% [markdown]
# # Data Science with Python
# by Ladislav Vrbsky
# for Estácio
#
# <a href='https://portal.estacio.br/'> <img src='https://portal.estacio.br/imgs/logo-estacio.png' /></a>

# %% [markdown]
# # Intro to Data Analysis

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn
np.random.seed(42)

# %%
df = pd.DataFrame(randn(4, 6), ['A', 'B', 'C', 'D'], ['q', 'w', 'e', 'r', 't', 'y'])

# %%
df
# Out:
#           q         w         e         r         t         y
# A  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
# B  1.579213  0.767435 -0.469474  0.542560 -0.463418 -0.465730
# C  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247
# D -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['w']
# Out:
# A   -0.138264
# B    0.767435
# C   -1.913280
# D   -1.412304
# Name: w, dtype: float64

# %%
type(df['w'])
# Out:
# pandas.core.series.Series

# %%
df.reset_index()
# Out:
#   index         q         w         e         r         t         y
# 0     A  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
# 1     B  1.579213  0.767435 -0.469474  0.542560 -0.463418 -0.465730
# 2     C  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247
# 3     D -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748

# %%
df.set_index('q')
# Out:
#                   w         e         r         t         y
# q
#  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
#  1.579213  0.767435 -0.469474  0.542560 -0.463418 -0.465730
#  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247
# -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748

# %%
df
# Out:
#           q         w         e         r         t         y
# A  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
# B  1.579213  0.767435 -0.469474  0.542560 -0.463418 -0.465730
# C  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247
# D -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748

# %%
df.iloc[0,1] = np.nan
df.loc['B',['r', 'y']] = np.nan

# %%
df
# Out:
#           q         w         e         r         t         y
# A  0.496714       NaN  0.647689  1.523030 -0.234153 -0.234137
# B  1.579213  0.767435 -0.469474       NaN -0.463418       NaN
# C  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247
# D -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748

# %%
df.dropna()
# Out:
#           q         w         e         r         t         y
# C  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247
# D -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748

# %%
df.fillna(42000.88)
# Out:
#           q             w         e             r         t             y
# A  0.496714  42000.880000  0.647689      1.523030 -0.234153     -0.234137
# B  1.579213      0.767435 -0.469474  42000.880000 -0.463418  42000.880000
# C  0.241962     -1.913280 -1.724918     -0.562288 -1.012831      0.314247
# D -0.908024     -1.412304  1.465649     -0.225776  0.067528     -1.424748

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 6 columns):
# q    4 non-null float64
# w    3 non-null float64
# e    4 non-null float64
# r    3 non-null float64
# t    4 non-null float64
# y    3 non-null float64
# dtypes: float64(6)
# memory usage: 384.0+ bytes

# %% [markdown]
# # Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 6 columns):
# q    4 non-null float64
# w    3 non-null float64
# e    4 non-null float64
# r    3 non-null float64
# t    4 non-null float64
# y    3 non-null float64
# dtypes: float64(6)
# memory usage: 384.0+ bytes

# %%
df.describe()
# Out:
#               q         w         e         r         t         y
# count  4.000000  3.000000  4.000000  3.000000  4.000000  3.000000
# mean   0.352466 -0.852716 -0.020264  0.244989 -0.410718 -0.448213
# std    1.020908  1.425276  1.385849  1.119532  0.456513  0.889043
# min   -0.908024 -1.913280 -1.724918 -0.562288 -1.012831 -1.424748
# 25%   -0.045534 -1.662792 -0.783335 -0.394032 -0.600771 -0.829443
# 50%    0.369338 -1.412304  0.089107 -0.225776 -0.348786 -0.234137
# 75%    0.767339 -0.322434  0.852179  0.648627 -0.158733  0.040055
# max    1.579213  0.767435  1.465649  1.523030  0.067528  0.314247

# %%
df.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# q    4.0  0.352466  1.020908 -0.908024 -0.045534  0.369338  0.767339  1.579213
# w    3.0 -0.852716  1.425276 -1.913280 -1.662792 -1.412304 -0.322434  0.767435
# e    4.0 -0.020264  1.385849 -1.724918 -0.783335  0.089107  0.852179  1.465649
# r    3.0  0.244989  1.119532 -0.562288 -0.394032 -0.225776  0.648627  1.523030
# t    4.0 -0.410718  0.456513 -1.012831 -0.600771 -0.348786 -0.158733  0.067528
# y    3.0 -0.448213  0.889043 -1.424748 -0.829443 -0.234137  0.040055  0.314247

# %%
df > 0
# Out:
#        q      w      e      r      t      y
# A   True  False   True   True  False  False
# B   True   True  False  False  False  False
# C   True  False  False  False  False   True
# D  False  False   True  False   True  False

# %%
df[df['r']>0]
# Out:
#           q   w         e        r         t         y
# A  0.496714 NaN  0.647689  1.52303 -0.234153 -0.234137

# %%
df_big = pd.DataFrame(randn(500, 60))

# %%
df_big
#df_big.head()
#df_big.head(10)
#df_big.tail()
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.544383  0.110923 -1.150994  0.375698 -0.600639 -0.291694 -0.601707
# 1   -0.808494 -0.501757  0.915402  0.328751 -0.529760  0.513267  0.097078
# 2    0.259883  0.781823 -1.236951 -1.320457  0.521942  0.296985  0.250493
# 3   -1.377669 -0.937825  0.515035  0.513786  0.515048  3.852731  0.570891
# 4   -0.252568 -1.247783  1.632411 -1.430141 -0.440044  0.130741  1.441273
# 5   -1.006017 -1.214189  1.158111  0.791663  0.624120  0.628346 -0.012247
# 6   -0.759133  0.150394  0.341756  1.876171  0.950424 -0.576904 -0.898415
# 7   -1.304470  0.669673  0.366598 -0.939880 -0.513867 -1.059214 -0.062679
# 8   -0.650643 -0.487125 -0.592394 -0.863991  0.048522 -0.830950  0.270457
# 9    1.201214 -0.408075 -2.038125 -1.008086 -1.870792 -0.351513  0.018418
# 10   1.593187 -0.511216 -0.989605 -0.125787  0.055725  1.094192 -1.692465
# 11  -1.222128  0.712998 -0.240325 -0.374821  0.710960  0.444263 -0.360966
# ...

# %%
df_big.describe()
# Out:
#                0           1           2           3           4           5   \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.018960    0.011171   -0.036560   -0.001962   -0.009514    0.028236
# std      0.997938    0.994024    1.024228    1.019700    0.996473    0.970204
# min     -2.820267   -2.783716   -3.321115   -2.899514   -2.990601   -2.707566
# 25%     -0.708060   -0.682365   -0.699374   -0.750027   -0.628138   -0.583586
# 50%     -0.015760   -0.002802   -0.017526   -0.012930   -0.009421    0.038126
# 75%      0.723955    0.678267    0.596777    0.736604    0.680055    0.642543
# max      2.902650    3.428910    3.602832    3.215374    3.377383    3.852731
#
#                6           7           8           9      ...              50  \
# count  500.000000  500.000000  500.000000  500.000000     ...      500.000000
# mean    -0.068822    0.050611    0.018932   -0.011575     ...       -0.027329
# ...

# %%
#df_big.describe().transpose()
df_big.describe().T
# Out:
#     count      mean       std       min       25%       50%       75%  \
# 0   500.0  0.018960  0.997938 -2.820267 -0.708060 -0.015760  0.723955
# 1   500.0  0.011171  0.994024 -2.783716 -0.682365 -0.002802  0.678267
# 2   500.0 -0.036560  1.024228 -3.321115 -0.699374 -0.017526  0.596777
# 3   500.0 -0.001962  1.019700 -2.899514 -0.750027 -0.012930  0.736604
# 4   500.0 -0.009514  0.996473 -2.990601 -0.628138 -0.009421  0.680055
# 5   500.0  0.028236  0.970204 -2.707566 -0.583586  0.038126  0.642543
# 6   500.0 -0.068822  1.052824 -2.954249 -0.786475 -0.082161  0.706604
# 7   500.0  0.050611  0.989690 -2.921350 -0.636146  0.027186  0.699238
# 8   500.0  0.018932  0.951606 -2.906988 -0.619436 -0.006663  0.650607
# 9   500.0 -0.011575  0.981503 -2.745300 -0.682856  0.016381  0.616886
# 10  500.0 -0.047760  0.961034 -3.335902 -0.685598 -0.070728  0.665311
# 11  500.0 -0.049977  1.007974 -2.936201 -0.665279 -0.058215  0.638491
# ...

# %%
df_big.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 60 columns):
# 0     500 non-null float64
# 1     500 non-null float64
# 2     500 non-null float64
# 3     500 non-null float64
# 4     500 non-null float64
# 5     500 non-null float64
# 6     500 non-null float64
# 7     500 non-null float64
# 8     500 non-null float64
# 9     500 non-null float64
# 10    500 non-null float64
# 11    500 non-null float64
# 12    500 non-null float64
# 13    500 non-null float64
# 14    500 non-null float64
# 15    500 non-null float64
# 16    500 non-null float64
# 17    500 non-null float64
# 18    500 non-null float64
# 19    500 non-null float64
# 20    500 non-null float64
# 21    500 non-null float64
# 22    500 non-null float64
# 23    500 non-null float64
# 24    500 non-null float64
# 25    500 non-null float64
# 26    500 non-null float64
# 27    500 non-null float64
# 28    500 non-null float64
# 29    500 non-null float64
# ...

# %%
df_big.loc[:,:5].corr().min()
# Out:
# 0   -0.093741
# 1   -0.030978
# 2   -0.002656
# 3   -0.028298
# 4   -0.093741
# 5   -0.030978
# dtype: float64

# %% [markdown]
# Observe the error and fix the expression.

# %%
#df.sort_values()
df.sort_values(by='e', ascending=False)
# Out:
#           q         w         e         r         t         y
# D -0.908024 -1.412304  1.465649 -0.225776  0.067528 -1.424748
# A  0.496714       NaN  0.647689  1.523030 -0.234153 -0.234137
# B  1.579213  0.767435 -0.469474       NaN -0.463418       NaN
# C  0.241962 -1.913280 -1.724918 -0.562288 -1.012831  0.314247

# %% [markdown]
# # Merge, Join, Concatenate

# %% [markdown]
# Prepare some sample data

# %%
np.random.seed(0)
df1 = pd.DataFrame(randn(4, 6), ['A', 'B', 'C', 'D'], ['q', 'w', 'e', 'r', 't', 'y'])
df2 = pd.DataFrame(randn(3, 4)+250, ['A', 'B', 'C'], ['u', 'i', 'o', 'p'])
df3 = pd.DataFrame(randn(4, 6)+350, ['A', 'B', 'C', 'D'], ['q', 'w', 'e', 'r', 't', 'y'])
df4 = pd.DataFrame(randn(4, 6)+450, ['C', 'D', 'E', 'F'], ['q', 'w', 'e', 'r', 't', 'y'])
df1_i = df1.reset_index()
df2_i = df2.reset_index()
df3_i = df3.reset_index()
df4_i = df4.reset_index()

# %%
df1.head()
# Out:
#           q         w         e         r         t         y
# A  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278
# B  0.950088 -0.151357 -0.103219  0.410599  0.144044  1.454274
# C  0.761038  0.121675  0.443863  0.333674  1.494079 -0.205158
# D  0.313068 -0.854096 -2.552990  0.653619  0.864436 -0.742165

# %%
df2.head()
# Out:
#             u           i           o           p
# A  252.269755  248.545634  250.045759  249.812816
# B  251.532779  251.469359  250.154947  250.378163
# C  249.112214  248.019204  249.652088  250.156349

# %%
df3.head()
# Out:
#             q           w           e           r           t           y
# A  351.230291  351.202380  349.612673  349.697697  348.951447  348.579982
# B  348.293730  351.950775  349.490348  349.561926  348.747205  350.777490
# C  348.386102  349.787260  349.104533  350.386902  349.489195  348.819368
# D  349.971818  350.428332  350.066517  350.302472  349.365678  349.637259

# %%
df4.head()
# Out:
#             q           w           e           r           t           y
# C  449.327540  449.640447  449.186854  448.273717  450.177426  449.598219
# D  448.369802  450.462782  449.092702  450.051945  450.729091  450.128983
# E  451.139401  448.765174  450.402342  449.315190  449.129203  449.421150
# F  449.688447  450.056165  448.834850  450.900826  450.465662  448.463756

# %% [markdown]
# ## Merge and Join

# %% [markdown]
# Inner join

# %%
df1_i.merge(df2_i, on='index')
# Out:
#   index         q         w         e         r         t         y  \
# 0     A  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278
# 1     B  0.950088 -0.151357 -0.103219  0.410599  0.144044  1.454274
# 2     C  0.761038  0.121675  0.443863  0.333674  1.494079 -0.205158
#
#             u           i           o           p
# 0  252.269755  248.545634  250.045759  249.812816
# 1  251.532779  251.469359  250.154947  250.378163
# 2  249.112214  248.019204  249.652088  250.156349

# %%
df1.merge(df2, left_index=True, right_index=True)
# Out:
#           q         w         e         r         t         y           u  \
# A  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278  252.269755
# B  0.950088 -0.151357 -0.103219  0.410599  0.144044  1.454274  251.532779
# C  0.761038  0.121675  0.443863  0.333674  1.494079 -0.205158  249.112214
#
#             i           o           p
# A  248.545634  250.045759  249.812816
# B  251.469359  250.154947  250.378163
# C  248.019204  249.652088  250.156349

# %% [markdown]
# Outer join

# %%
df1_i.merge(df2_i, on='index', how='outer')
# Out:
#   index         q         w         e         r         t         y  \
# 0     A  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278
# 1     B  0.950088 -0.151357 -0.103219  0.410599  0.144044  1.454274
# 2     C  0.761038  0.121675  0.443863  0.333674  1.494079 -0.205158
# 3     D  0.313068 -0.854096 -2.552990  0.653619  0.864436 -0.742165
#
#             u           i           o           p
# 0  252.269755  248.545634  250.045759  249.812816
# 1  251.532779  251.469359  250.154947  250.378163
# 2  249.112214  248.019204  249.652088  250.156349
# 3         NaN         NaN         NaN         NaN

# %%
df1.join(df2)
# Out:
#           q         w         e         r         t         y           u  \
# A  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278  252.269755
# B  0.950088 -0.151357 -0.103219  0.410599  0.144044  1.454274  251.532779
# C  0.761038  0.121675  0.443863  0.333674  1.494079 -0.205158  249.112214
# D  0.313068 -0.854096 -2.552990  0.653619  0.864436 -0.742165         NaN
#
#             i           o           p
# A  248.545634  250.045759  249.812816
# B  251.469359  250.154947  250.378163
# C  248.019204  249.652088  250.156349
# D         NaN         NaN         NaN

# %% [markdown]
# ## Concatenate

# %%
pd.concat([df1_i,df2_i,df3_i,df4_i], sort=False)
# Out:
#   index           q           w           e           r           t  \
# 0     A    1.764052    0.400157    0.978738    2.240893    1.867558
# 1     B    0.950088   -0.151357   -0.103219    0.410599    0.144044
# 2     C    0.761038    0.121675    0.443863    0.333674    1.494079
# 3     D    0.313068   -0.854096   -2.552990    0.653619    0.864436
# 0     A         NaN         NaN         NaN         NaN         NaN
# 1     B         NaN         NaN         NaN         NaN         NaN
# 2     C         NaN         NaN         NaN         NaN         NaN
# 0     A  351.230291  351.202380  349.612673  349.697697  348.951447
# 1     B  348.293730  351.950775  349.490348  349.561926  348.747205
# 2     C  348.386102  349.787260  349.104533  350.386902  349.489195
# 3     D  349.971818  350.428332  350.066517  350.302472  349.365678
# 0     C  449.327540  449.640447  449.186854  448.273717  450.177426
# 1     D  448.369802  450.462782  449.092702  450.051945  450.729091
# ...

# %%
pd.concat([df1,df2,df3,df4], axis=1, sort=False)#.T
# Out:
#           q         w         e         r         t         y           u  \
# A  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278  252.269755
# B  0.950088 -0.151357 -0.103219  0.410599  0.144044  1.454274  251.532779
# C  0.761038  0.121675  0.443863  0.333674  1.494079 -0.205158  249.112214
# D  0.313068 -0.854096 -2.552990  0.653619  0.864436 -0.742165         NaN
# E       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# F       NaN       NaN       NaN       NaN       NaN       NaN         NaN
#
#             i           o           p     ...               e           r  \
# A  248.545634  250.045759  249.812816     ...      349.612673  349.697697
# B  251.469359  250.154947  250.378163     ...      349.490348  349.561926
# C  248.019204  249.652088  250.156349     ...      349.104533  350.386902
# D         NaN         NaN         NaN     ...      350.066517  350.302472
# E         NaN         NaN         NaN     ...             NaN         NaN
# ...

# %% [markdown]
# But in this case, we would have various columns with the same name.

# %%
pd.concat([df1,df2,df3,df4], axis=1, sort=False)['q']
# Out:
#           q           q           q
# A  1.764052  351.230291         NaN
# B  0.950088  348.293730         NaN
# C  0.761038  348.386102  449.327540
# D  0.313068  349.971818  448.369802
# E       NaN         NaN  451.139401
# F       NaN         NaN  449.688447

# %% [markdown]
# Let's use a prefix to distinguish the columns

# %%
#df3.add_prefix('df3_')

# %%
pd.concat([df1,df3.add_prefix('df3_')], axis=1, sort=False)
# Out:
#           q         w         e         r         t         y       df3_q  \
# A  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278  351.230291
# B  0.950088 -0.151357 -0.103219  0.410599  0.144044  1.454274  348.293730
# C  0.761038  0.121675  0.443863  0.333674  1.494079 -0.205158  348.386102
# D  0.313068 -0.854096 -2.552990  0.653619  0.864436 -0.742165  349.971818
#
#         df3_w       df3_e       df3_r       df3_t       df3_y
# A  351.202380  349.612673  349.697697  348.951447  348.579982
# B  351.950775  349.490348  349.561926  348.747205  350.777490
# C  349.787260  349.104533  350.386902  349.489195  348.819368
# D  350.428332  350.066517  350.302472  349.365678  349.637259

# %% [markdown]
# Preserve the first `df1` as suggested in the [pandas docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
# If you prefer, transpose the DataFrame to see it better

# %%
#normal
#pd.concat([df1,df2.reindex(df1.index),df3.reindex(df1.index),df4.reindex(df1.index)], axis=1)
#transposed
pd.concat([df1,df2.reindex(df1.index),df3.reindex(df1.index),df4.reindex(df1.index)], axis=1).T
# Out:
#             A           B           C           D
# q    1.764052    0.950088    0.761038    0.313068
# w    0.400157   -0.151357    0.121675   -0.854096
# e    0.978738   -0.103219    0.443863   -2.552990
# r    2.240893    0.410599    0.333674    0.653619
# t    1.867558    0.144044    1.494079    0.864436
# y   -0.977278    1.454274   -0.205158   -0.742165
# u  252.269755  251.532779  249.112214         NaN
# i  248.545634  251.469359  248.019204         NaN
# o  250.045759  250.154947  249.652088         NaN
# p  249.812816  250.378163  250.156349         NaN
# q  351.230291  348.293730  348.386102  349.971818
# w  351.202380  351.950775  349.787260  350.428332
# e  349.612673  349.490348  349.104533  350.066517
# r  349.697697  349.561926  350.386902  350.302472
# t  348.951447  348.747205  349.489195  349.365678
# y  348.579982  350.777490  348.819368  349.637259
# q         NaN         NaN  449.327540  448.369802
# w         NaN         NaN  449.640447  450.462782
# ...

# %% [markdown]
# # Visualization

# %%
#put imports in the first cell instead
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('ggplot')
#plt.style.use('bmh')
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
sns.pairplot(df_big.loc[:,:5])

# %%
df_big.loc[:,:5].corr()
# Out:
#           0         1         2         3         4         5
# 0  1.000000  0.027855  0.031831 -0.019014 -0.093741  0.060440
# 1  0.027855  1.000000  0.038057  0.063519  0.001463 -0.030978
# 2  0.031831  0.038057  1.000000  0.023164  0.034887 -0.002656
# 3 -0.019014  0.063519  0.023164  1.000000 -0.017897 -0.028298
# 4 -0.093741  0.001463  0.034887 -0.017897  1.000000  0.042563
# 5  0.060440 -0.030978 -0.002656 -0.028298  0.042563  1.000000

# %%
sns.heatmap(df_big.loc[:,:5].corr(), cmap='viridis')

# %%
sns.distplot(df_big[3])
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_big.plot(x=0, y=1, kind='scatter')

# %%
df_big[[1,2]].hist(figsize=[12,8])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bf6ceb8>,
# ...
#       dtype=object)
